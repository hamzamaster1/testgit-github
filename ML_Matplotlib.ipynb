# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
plt.plot?

# %%
plt.plot(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(2,3, '.')

# %% [markdown]
# # Scatter Plot

# %%
import numpy as np

x = np.array([1,2,3,4,5,6,7,8])
y = x

plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
colors = ['green']*(len(x)-1)
colors.append('red')

# %%
plt.figure()
plt.scatter(x,y ,c=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('number of friends')
plt.ylabel('timeon social media')
plt.title('Time spent')

# %% [markdown]
# # Line

# %%
#plt.figure()
plt.plot(x,'-o')

# %%
import numpy as np

linear_data = np.array([1,2,3,4,5,6,7,8])
exponential_data = linear_data**2

plt.figure()
# plot the linear data and the exponential data
plt.plot(linear_data, '-o', exponential_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# # Bar

# %%
plt.figure()
plt.bar(range(len(linear_data)),linear_data)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 8 artists>

# %%
plt.figure()
plt.bar(range(len(linear_data)),exponential_data)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 8 artists>

# %%
plt.figure()
plt.boxplot(linear_data)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'boxes': [<matplotlib.lines.Line2D at 0x15a681b1a58>],
#  'caps': [<matplotlib.lines.Line2D at 0x15a681bd588>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x15a681c62e8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x15a681bde48>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x15a681b1c18>,
#   <matplotlib.lines.Line2D at 0x15a681bd128>]}

# %% [markdown]
# # Subplot

# %%
exponential_data = linear_data**2 
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 2nd subplot axes
plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1,2,1)
plt.plot(linear_data, '-o')

# %% [markdown]
# # Pandas Plot

# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# 7            5.0         3.4          1.5         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 11           4.8         3.4          1.6         0.2     Iris-setosa
# ...

# %%
df.plot('SepalLength' , 'SepalWidth' ,kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ###
# You can also choose the plot kind by using the DataFrame.plot.kind methods instead of providing the kind keyword argument.
#
# kind :
#
#     'line' : line plot (default)
#     'bar' : vertical bar plot
#     'barh' : horizontal bar plot
#     'hist' : histogram
#     'box' : boxplot
#     'kde' : Kernel Density Estimation plot
#     'density' : same as 'kde'
#     'area' : area plot
#     'pie' : pie plot
#     'scatter' : scatter plot
#     'hexbin' : hexbin plot
